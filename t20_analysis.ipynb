# %% [markdown]
# # 2022-2024 T20 world cup top-record analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# Load the Excel file
df = pd.read_excel("t20_2022_battings.xlsx", sheet_name="Sheet1")

# save it as numpy array
numpy_arr=df.to_numpy()

#Save it as CSV
df.to_csv("t20_2022.csv", index=False)
print(df)

print("Excel sheet converted to CSV successfully!")
# Out:
#        Player Team  MATCH  INNING  NO.  RUNS   HS  SIX  FOURS  STR.R  HUN.S  \
# 0       Virat  IND      6       6    3   296   82    8     25    136    NaN
# 1      O'Dowd  NED      8       8    1   242   71    8     22    112    NaN
# 2       Yadav  IND      6       6    2   239   68    9     26    189    NaN
# 3  JC Buttler  ENG      6       6    1   225   80    7     24    144    NaN
# 4      Mendis   SL      8       8    1   223   79   10     17    142    NaN
# 5        Raza  ZIM      8       8    3   219   82   11     16    147    NaN
# 6  P.Nissanka   SL      7       7    3   214   74    8     13    109    NaN
# 7       Hales  ENG      6       6    1   212   86   10     19    147    NaN
# 8       Tcker  IRE      7       7    2   204   71    4     19    125    NaN
# 9    Phillips   NZ      5       5    4   201  104    8     19    127    1.0
#
#    FIF.S
# 0      4
# 1      2
# 2      3
# 3      2
# 4      2
# 5      1
# 6      2
# 7      2
# 8      1
# 9      1
# ...

# %%
import pandas as pd 
import numpy as np
# Load the Excel file
df2 = pd.read_excel("t20_2024_batting.xlsx", sheet_name="Sheet1")

# save it as numpy array
numpy_arr=df2.to_numpy()

#Save it as CSV
df2.to_csv("t20_2024.csv", index=False)
print(df2)

print("Excel sheet converted to CSV successfully!")
# Out:
#      PLAYER TEAM  RUN  MATCH   INNING  HS  FOURS  SIX  HUN.S  FIF.S
# 0    GURBAZ  AFG  281       8       8  84     18   16    NaN      3
# 1     ROHIT  IND  257       8       8  92     24   15    NaN      3
# 2      HEAD  AUS  255       9       9  76     26   15    NaN      2
# 3   DE KOCK   SA  243       8       8  74     21   13    NaN      2
# 4   INRAHIM  AFG  231       7       7  70     25    4    NaN      2
# 5    POORAN   WI  228       6       6  98     15   17    NaN      1
# 6      GOUS  USA  219       8       8  80     20   11    NaN      2
# 7  BUTTLLER  ENG  214       8       7  83     22   10    NaN      1
# 8       SKY  IND  199       9       9  53     15   10    NaN      2
# 9   KLAASEN   SA  190       8       7  52      9   13    NaN      1
# Excel sheet converted to CSV successfully!

# %%
import matplotlib.pyplot as plt
runs_array=np.array(df["RUNS"])
players=np.array(df["Player"])
run2=np.array(df2["RUN"])
player2=np.array(df2["PLAYER"])
plt.figure(figsize=(20,10))
plt.bar(players, runs_array)
plt.bar(player2, run2, alpha=0.7)
plt.legend(["T20 2022", "T20 2024"])
plt.xlabel("Players")
plt.ylabel("Runs Scored")
plt.title("T20 2022 and 2024 Runs by Players")

plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# Load the Excel file
df = pd.read_excel("t20_2022_battings.xlsx", sheet_name="Sheet1")

# save it as numpy array
numpy_arr=df.to_numpy()

#Save it as CSV
df.to_csv("t20_2022.csv", index=False)
# print(df)

print("Excel sheet converted to CSV successfully!")
import pandas as pd 
import numpy as np
# Load the Excel file
df2 = pd.read_excel("t20_2024_batting.xlsx", sheet_name="Sheet1")

# save it as numpy array
numpy_arr=df2.to_numpy()

#Save it as CSV
df2.to_csv("t20_2024.csv", index=False)


print("Excel sheet converted to CSV successfully!")
# making pie graph for boundariescalculating fours 
# calculating fours 

four_2022=df["FOURS"].sum()
print("total fours by all this top 10 scores in 2022=",four_2022)

four_2024=df2["FOURS"].sum()
print("total fours by all this top 10 scores in 2024=",four_2024)

# calculating sixes
six_2022=df["SIX"].sum()
print("total sixes by all this top 10 scores in 2022=",six_2022)

six_2024=df2["SIX"].sum()
print("total sixes by all this top 10 scores in 2024=",six_2024)

# total boundaries
total_boundaries=four_2022+six_2022
print("total boundaries in 2022=",total_boundaries)

total_boundaries_2024=four_2024+six_2024
print("total boundaries in 2024=",total_boundaries_2024)

#pie chart
plt.figure(figsize=(6,6))
plt.pie([four_2022,six_2022] , labels=["Fours","Sixes"],autopct='%1.1f%%', startangle=140)
plt.legend(title="Boundaries",loc="upper right")
plt.title("Distribution of Fours and Sixes in T20 2022")
plt.show()
plt.figure(figsize=(6,6))
plt.pie([four_2024,six_2024] , labels=["Fours","Sixes"],autopct='%1.1f%%', startangle=140 , colors=['lightblue', 'lightgreen'])
plt.legend(title="Boundaries",loc="upper right")
plt.title("Distribution of Fours and Sixes in T20 2024")
plt.show()
# Out:
# Excel sheet converted to CSV successfully!
# Excel sheet converted to CSV successfully!
# total fours by all this top 10 scores in 2022= 200
# total fours by all this top 10 scores in 2024= 195
# total sixes by all this top 10 scores in 2022= 83
# total sixes by all this top 10 scores in 2024= 124
# total boundaries in 2022= 283
# total boundaries in 2024= 319

# %%
import pandas as pd 
import numpy as np

# Load the BALLING Excel file(2022)
df=pd.read_excel("t20_2022_balling.xlsx", sheet_name="Sheet1")
df.to_numpy()
df.to_csv("t20.2022_balling.csv")
print(df)

#LOAD THE BALLING EXCEL FILE(2024)
df2=pd.read_excel("t20_2024_balling.xlsx", sheet_name="Sheet1")
df2.to_numpy()
df2.to_csv("t20.2024_balling.csv")
print(df2)
eco2=np.array(df2["ECON."])
name2=np.array(df2["TEAM"])
eco=np.array(df["ECON."])
name=np.array(df["TEAM"])
plt.figure(figsize=(20,10))
plt.bar(name, eco, color='orange', alpha=0.5, edgecolor='black', linewidth=1.2, label='2022 Economy Rate')
plt.bar(name2, eco2, color='blue', alpha=0.5, edgecolor='black', linewidth=1.2, label='2024 Economy Rate')
plt.legend(["2022","2024"], loc='upper right')
plt.xlabel("TEAM ")
plt.ylabel("ECONOMY")
plt.title("T20_2022 & 2024 Economy Rate by Players")
plt.show()


# catches analysis in the 2024
df3=pd.read_excel("2024_catches.xlsx", sheet_name="Sheet1")
df3.to_csv("2024_catches.csv")
print(df3)
tot_catches=df3["CATCHES"].sum()
print("total catches in 2024=",tot_catches)
catches_team=np.array(df3["Team"])
catches_num=np.array(df3["CATCHES"])

# catches analysis IN 2022
df4=pd.read_excel("2022_catches.xlsx", sheet_name="Sheet1")
df4.to_csv("2022_catches.csv")
print(df4)
tot_catches_2022=df4["Catches"].sum()
print("total catches in 2022=",tot_catches_2022)
catches_team_2022=np.array(df4["Team"])
catches_num_2022=np.array(df4["Catches"])

plt.figure(figsize=(10,6))
plt.scatter(catches_team, catches_num, color='green', s=50)
plt.scatter(catches_team_2022, catches_num_2022, color='red', s=50)
plt.xlabel("Teams")
plt.ylabel("Number of Catches")
plt.title("Catches by Teams in 2024 T20")
plt.grid(True)
plt.show()
print("TOP SCORER FOR ")
print("_"*50)
print("TOP scorer for indian  team in last 2 T20 world cup  is SK YADAV with 438 runs in 15 innings ",)
print("Top wicket taking bowler for INDIAN team in last  34 T20 world cup is ARSHDEEP SINGH  with 17 WICKETS ")
print("Total successful catches by INDIAN team in = 34  ")
# Out:
#        PLAYER  TEAM  MAT  INN  OVERS  RUNS  WKTS  ECON.
# 0    HASARANGA   SL    8    8     31   186    15   6.14
# 1       CURRAN  ENG    6    6     22   199    13   7.68
# 2       LEEDDE  NED    8    7     22   148    13   7.65
# 3   MUZARABANI  ZIM    8    7     26   169    12   5.37
# 4        NORJE   SA    5    5     17   199    11   6.52
# 5       AFRIDI  PAK    7    7     25    94    11   6.15
# 6  SHADAB KHAN  PAK    7    7     26   155    11   6.34
# 7      MEEKREN  NED    8    8     31   165    11   6.34
# 8       LITTLE  IRE    7    7     27   189    11   7.00
# 9         RAZA  ZIM    8    8     24   156    10   6.50
#      PLAYER  TEAM  MAT  INN  OVER  RUNS  WKTS  ECON.
# 0    FAROOQI  AFG    8    8    25   160    17   6.01
# 1   ARSHDEEP  IND    8    8    23   215    17   6.53
# 2     BUMRAH  IND    8    8    24   124    15   6.10
# 3     NORTJE   SA    9    9    35   201    15   4.67
# 4     RASHID  AFG    8    8    29   179    14   5.74
# ...
